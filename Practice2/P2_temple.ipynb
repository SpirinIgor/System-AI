# %% [markdown]
# # Практическая работа №2
# ## Тема: «Операции с данными»
# ### Выполнил студент: ???
# #### ВАРИАНТ: ???

# %% [markdown]
# #### Задание 1. Очистка пустых значений

# %%
import pandas as pd
import numpy as np

df = pd.read_excel('datasets\Data1.xlsx', sheet_name = '1')

# %%
df
# Out:
#      №     Фамилия         Имя       Отчество     1     2     3     4     5  \
# 0    1     Абрамов      Руслан      Закирович  24.0  45.0  67.0  23.0  90.0
# 1    2    Байтоков     Ниязбек      Дулатович   NaN  12.0   2.0  45.0  65.0
# 2    3    Боярская  Владислава  Александровна  34.0  67.0  68.0  12.0  65.0
# 3    4  Григорьева   Анастасия     Алексеевна   NaN  67.0  34.0  67.0  65.0
# 4    5    Ефименко   Александр      Андреевич   NaN  12.0  54.0  45.0   3.0
# 5    6      Иванов        Егор     Николаевич  34.0   NaN   NaN  12.0  65.0
# 6    7   Казакевич    Ангелина     Витальевна   NaN  45.0   NaN  54.0  65.0
# 7    8     Кащенко     Виталий      Андреевич   NaN   NaN   NaN   NaN   NaN
# 8    9      Кладий   Александр      Сергеевич   NaN  12.0  54.0  45.0  65.0
# 9   10     Климков       Артем     Алексеевич   NaN   NaN   NaN  12.0  65.0
# 10  11     Кожаева       Арина      Сергеевна  24.0  45.0  67.0  23.0  90.0
# ...

# %%
df.shape
# Out:
# (22, 14)

# %%
df.isnull().sum()
# Out:
# №            0
# Фамилия      0
# Имя          0
# Отчество     1
# 1           13
# 2            5
# 3            7
# 4            2
# 5            2
# 6            6
# 7            6
# 8            6
# 9           11
# 10           8
# dtype: int64
